# %%
# !pip install opendatasets
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#      ---------------------------------------- 82.7/82.7 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#      -------------------------------------- 163.4/163.4 kB 3.3 MB/s eta 0:00:00
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# ...
#      ---------------------------------------- 78.2/78.2 kB 4.5 MB/s eta 0:00:00
# ...
#   Running setup.py install for kaggle: started
#   Running setup.py install for kaggle: finished with status 'done'
# ...
#   DEPRECATION: kaggle is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# ...

# %%
import opendatasets as od
url = "https://www.kaggle.com/datasets/aadyasingh55/cocktails"
od.download(url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/aadyasingh55/cocktails
# ...
# 100%|██████████| 52.1k/52.1k [00:00<00:00, 425kB/s]

# %%
import os
os.listdir()
dir = "cocktails/"
df_csv = dir + "final_cocktails.csv"

# %%
import pandas as pd
df = pd.read_csv(df_csv,index_col=0 )
df.head(5)
# Out:
#    id  name  alcoholic        category       glassType  \
# 0   0    A1  Alcoholic        Cocktail  Cocktail glass
# 1   1   ABC  Alcoholic            Shot      Shot glass
# 2   2   Ace  Alcoholic        Cocktail   Martini Glass
# 3   3  ACID  Alcoholic            Shot      Shot glass
# 4   4  Adam  Alcoholic  Ordinary Drink  Cocktail glass
#
#                                         instructions  \
# 0  Pour all ingredients into a cocktail shaker, m...
# 1                           Layered in a shot glass.
# 2  Shake all the ingredients in a cocktail shaker...
# 3  Poor in the 151 first followed by the 101 serv...
# 4  In a shaker half-filled with ice cubes, combin...
#
#                                       drinkThumbnail  \
# 0  https://www.thecocktaildb.com/images/media/dri...
# 1  https://www.thecocktaildb.com/images/media/dri...
# 2  https://www.thecocktaildb.com/images/media/dri...
# 3  https://www.thecocktaildb.com/images/media/dri...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 425 entries, 0 to 424
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  425 non-null    int64
#  1   name                425 non-null    object
#  2   alcoholic           425 non-null    object
#  3   category            425 non-null    object
#  4   glassType           425 non-null    object
#  5   instructions        425 non-null    object
#  6   drinkThumbnail      425 non-null    object
#  7   ingredients         425 non-null    object
#  8   ingredientMeasures  425 non-null    object
#  9   text                425 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 36.5+ KB

# %%
df.isnull().sum()
# Out:
# id                    0
# name                  0
# alcoholic             0
# category              0
# glassType             0
# instructions          0
# drinkThumbnail        0
# ingredients           0
# ingredientMeasures    0
# text                  0
# dtype: int64

# %%
documents = df["ingredients"].apply(lambda x: {"content": x}).tolist()
documents
# Out:
# [{'content': "['Gin', 'Grand Marnier', 'Lemon Juice', 'Grenadine']"},
#  {'content': "['Amaretto', 'Baileys irish cream', 'Cognac']"},
#  {'content': "['Gin', 'Grenadine', 'Heavy cream', 'Milk', 'Egg White']"},
#  {'content': "['151 proof rum', 'Wild Turkey']"},
#  {'content': "['Dark rum', 'Lemon juice', 'Grenadine']"},
#  {'content': "['Absolut Vodka', 'Gin', 'Tonic water']"},
#  {'content': "['Applejack', 'Grapefruit juice']"},
#  {'content': "['Vodka', 'Pisang Ambon', 'Apple juice', 'Lemon juice', 'Lemonade']"},
#  {'content': "['Orange juice', 'Grapefruit juice', 'Apple juice', 'Maraschino cherry']"},
#  {'content': "['Strawberry schnapps', 'Orange juice', 'Cranberry juice', 'Club soda']"},
#  {'content': "['Dark rum', 'Peach nectar', 'Orange juice']"},
#  {'content': "['Dark rum', 'Kahlua', 'Egg white']"},
#  {'content': "['Gin', 'Vermouth']"},
#  {'content': "['Applejack', 'Triple sec', 'Lemon juice']"},
# ...
